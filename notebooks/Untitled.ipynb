# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# Retrieve stored dataframe
# %store -r table1_hzm

#Set precision of pandas to 2 
#pd.set_option('precision', 2)

#Print table1_hzm
table1_hzm

pd.reset_option('precision')

# %%
table1_hzm
# Out:
#     Star      HZ Atmosphere   Pigment    gamma_t    gamma_B   gamma_Q  \
# 0    Sun  middle        os1      ChlA   1.000000   0.000000  0.000000
# 1    a5v     hzm        os1     BChlA  11.421699   4.775585  6.646113
# 2    a5v     hzm        os1     BChlB  15.682876   8.915904  6.766972
# 3    a5v     hzm        os1      ChlA  13.535886   9.790268  3.745617
# 4    a5v     hzm        os1      ChlB  16.235056  12.963893  3.271163
# ..   ...     ...        ...       ...        ...        ...       ...
# 96   m8v     hzm        os4     BChlA   1.028818   0.001721  1.027097
# 97   m8v     hzm        os4     BChlB   1.822631   0.004198  1.818433
# 98   m8v     hzm        os4      ChlA   0.075462   0.002624  0.072838
# 99   m8v     hzm        os4      ChlB   0.065527   0.016697  0.048829
# 100  m8v     hzm        os4  Phot0-Zn   0.020410   0.000464  0.019946
#
#             ppfd         S
# 0       0.000000     0.000
# 1    2400.479453  1370.042
# 2    2400.479453  1370.042
# 3    2400.479453  1370.042
# 4    2400.479453  1370.042
# ..           ...       ...
# 96     17.983625  1370.042
# 97     17.983625  1370.042
# 98     17.983625  1370.042
# 99     17.983625  1370.042
# 100    17.983625  1370.042
#
# [101 rows x 9 columns]

# %%
data=table1_hzm[table1_hzm(['Star']=='g2v' & ['Atmosphere']=='os4')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16836/859959688.py in <module>
# ----> 1 data=table1_hzm[table1_hzm(['Star']=='g2v' & ['Atmosphere']=='os4')]
#
# TypeError: unsupported operand type(s) for &: 'str' and 'list'

# %%
data
# Out:
#    Star   HZ Atmosphere   Pigment    gamma_t    gamma_B    gamma_Q  \
# 21  g2v  hzi        os1     BChlA  22.052097   4.729927  17.322170
# 22  g2v  hzi        os1     BChlB  26.942932   8.705350  18.237583
# 23  g2v  hzi        os1      ChlA  17.630934   8.914423   8.716512
# 24  g2v  hzi        os1      ChlB  21.346741  14.385824   6.960918
# 25  g2v  hzi        os1  Phot0-Zn  10.418980   2.073411   8.345568
# 26  g2v  hzi        os2     BChlA  21.157534   3.153973  18.003560
# 27  g2v  hzi        os2     BChlB  25.187033   6.170033  19.017000
# 28  g2v  hzi        os2      ChlA  15.023227   6.467054   8.556173
# 29  g2v  hzi        os2      ChlB  18.022219  11.228032   6.794187
# 30  g2v  hzi        os2  Phot0-Zn   9.012187   1.108450   7.903737
# 31  g2v  hzi        os3     BChlA  23.443041   4.725196  18.717846
# 32  g2v  hzi        os3     BChlB  28.349089   8.642281  19.706807
# 33  g2v  hzi        os3      ChlA  17.975880   8.935155   9.040725
# 34  g2v  hzi        os3      ChlB  21.594103  14.348737   7.245365
# 35  g2v  hzi        os3  Phot0-Zn  10.654962   2.037846   8.617115
# 36  g2v  hzi        os4     BChlA  25.573660   6.371269  19.202390
# 37  g2v  hzi        os4     BChlB  31.228796  11.059721  20.169075
# 38  g2v  hzi        os4      ChlA  20.728920  11.341578   9.387342
# 39  g2v  hzi        os4      ChlB  24.729568  17.158628   7.570940
# 40  g2v  hzi        os4  Phot0-Zn  12.299210   3.160699   9.138510
# 41  g2v  hzm        os1     BChlA  11.512597   2.469233   9.043365
# 42  g2v  hzm        os1     BChlB  14.065592   4.544452   9.521140
# 43  g2v  hzm        os1      ChlA   9.204160   4.653584   4.550575
# 44  g2v  hzm        os1      ChlB  11.143878   7.509786   3.634092
# 45  g2v  hzm        os1  Phot0-Zn   5.439474   1.082405   4.357069
# 46  g2v  hzm        os2     BChlA  11.031096   1.637764   9.393331
# 47  g2v  hzm        os2     BChlB  13.129623   3.206704   9.922920
# 48  g2v  hzm        os2      ChlA   7.824744   3.361640   4.463105
# 49  g2v  hzm        os2      ChlB   9.386100   5.842516   3.543583
# 50  g2v  hzm        os2  Phot0-Zn   4.695006   0.573946   4.121061
# 51  g2v  hzm        os3     BChlA  12.228123   2.459690   9.768433
# 52  g2v  hzm        os3     BChlB  14.785706   4.500911  10.284795
# 53  g2v  hzm        os3      ChlA   9.371470   4.653860   4.717610
# 54  g2v  hzm        os3      ChlB  11.258165   7.477629   3.780537
# 55  g2v  hzm        os3  Phot0-Zn   5.554963   1.059313   4.495650
# 56  g2v  hzm        os4     BChlA  13.346025   3.322984  10.023041
# 57  g2v  hzm        os4     BChlB  16.296864   5.769159  10.527704
# 58  g2v  hzm        os4      ChlA  10.816002   5.916270   4.899732
# 59  g2v  hzm        os4      ChlB  12.903901   8.952304   3.951598
# 60  g2v  hzm        os4  Phot0-Zn   6.417427   1.647855   4.769572
# 61  g2v  hzo        os1     BChlA   9.033899   1.937686   7.096213
# 62  g2v  hzo        os1     BChlB  11.037130   3.566039   7.471091
# 63  g2v  hzo        os1      ChlA   7.222839   3.651665   3.571175
# 64  g2v  hzo        os1      ChlB   8.744925   5.892926   2.851999
# 65  g2v  hzo        os1  Phot0-Zn   4.268903   0.849382   3.419522
# 66  g2v  hzo        os2     BChlA   8.676645   1.298261   7.378384
# 67  g2v  hzo        os2     BChlB  10.331711   2.537957   7.793754
# 68  g2v  hzo        os2      ChlA   6.167030   2.659765   3.507265
# 69  g2v  hzo        os2      ChlB   7.399027   4.613664   2.785362
